# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("superstore.csv")

# %% [markdown]
# # Data preparation

# %%
df.head()
# Out:
#      Order Date  Ship Date       Ship Mode  Customer Name      Segment  \
# 7980 2015-01-03 2015-01-07  Standard Class  Darren Powers     Consumer
# 741  2015-01-04 2015-01-08  Standard Class  Phillina Ober  Home Office
# 740  2015-01-04 2015-01-08  Standard Class  Phillina Ober  Home Office
# 739  2015-01-04 2015-01-08  Standard Class  Phillina Ober  Home Office
# 1759 2015-01-05 2015-01-12  Standard Class     Mick Brown     Consumer
#
#             Country          City         State  Postal Code   Region  \
# 7980  United States       Houston         Texas      77095.0  Central
# 741   United States    Naperville      Illinois      60540.0  Central
# 740   United States    Naperville      Illinois      60540.0  Central
# 739   United States    Naperville      Illinois      60540.0  Central
# 1759  United States  Philadelphia  Pennsylvania      19143.0     East
#
#            Product ID         Category Sub-Category  \
# 7980  OFF-PA-10000174  Office Supplies        Paper
# 741   OFF-BI-10004094  Office Supplies      Binders
# 740   OFF-ST-10002743  Office Supplies      Storage
# 739   OFF-LA-10003223  Office Supplies       Labels
# 1759  OFF-AR-10003478  Office Supplies          Art
#
#                                            Product Name    Sales
# 7980  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448
# 741          GBC Standard Plastic Binding Systems Combs    3.540
# 740                       SAFCO Boltless Steel Shelving  272.736
# 739                                           Avery 508   11.784
# 1759  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9800 entries, 7980 to 5091
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9800 non-null   datetime64[ns]
#  1   Ship Date      9800 non-null   datetime64[ns]
#  2   Ship Mode      9800 non-null   object
#  3   Customer Name  9800 non-null   object
#  4   Segment        9800 non-null   object
#  5   Country        9800 non-null   object
#  6   City           9800 non-null   object
#  7   State          9800 non-null   object
#  8   Postal Code    9800 non-null   float64
#  9   Region         9800 non-null   object
#  10  Product ID     9800 non-null   object
#  11  Category       9800 non-null   object
#  12  Sub-Category   9800 non-null   object
#  13  Product Name   9800 non-null   object
#  14  Sales          9800 non-null   float64
# dtypes: datetime64[ns](2), float64(2), object(11)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9800                           9800
# mean   2017-05-01 05:13:51.673469440  2017-05-05 04:17:52.653061120
# min              2015-01-03 00:00:00            2015-01-07 00:00:00
# 25%              2016-05-24 00:00:00            2016-05-27 18:00:00
# 50%              2017-06-26 00:00:00            2017-06-29 00:00:00
# 75%              2018-05-15 00:00:00            2018-05-19 00:00:00
# max              2018-12-30 00:00:00            2019-01-05 00:00:00
# std                              NaN                            NaN
#
#         Postal Code         Sales
# count   9800.000000   9800.000000
# mean   55217.343265    230.769059
# min     1040.000000      0.444000
# 25%    23223.000000     17.248000
# 50%    57551.000000     54.490000
# 75%    90008.000000    210.605000
# max    99301.000000  22638.480000
# std    32066.750532    626.651875

# %%
df.drop(["Row ID","Order ID","Customer ID"],inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.drop(["Row ID","Order ID","Customer ID"],inplace=True, axis=1)
#
# File d:\Praca\Projekty\Data Analysis\Superstore Sales Analysis\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File d:\Praca\Projekty\Data Analysis\Superstore Sales Analysis\.venv\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File d:\Praca\Projekty\Data Analysis\Superstore Sales Analysis\.venv\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File d:\Praca\Projekty\Data Analysis\Superstore Sales Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Row ID', 'Order ID', 'Customer ID'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9800 non-null   object
#  1   Ship Date      9800 non-null   object
#  2   Ship Mode      9800 non-null   object
#  3   Customer Name  9800 non-null   object
#  4   Segment        9800 non-null   object
#  5   Country        9800 non-null   object
#  6   City           9800 non-null   object
#  7   State          9800 non-null   object
#  8   Postal Code    9789 non-null   float64
#  9   Region         9800 non-null   object
#  10  Product ID     9800 non-null   object
#  11  Category       9800 non-null   object
#  12  Sub-Category   9800 non-null   object
#  13  Product Name   9800 non-null   object
#  14  Sales          9800 non-null   float64
# dtypes: float64(2), object(13)
# memory usage: 1.1+ MB

# %%
# Change format to date time
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d/%m/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%d/%m/%Y')

# %%
# Sort by date
df.sort_values(by=['Order Date'], inplace=True, ascending=True)

# %%
# Fixing nulls
df.isnull().sum()
# Out:
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df[df['Postal Code'].isnull()]
# Out:
#      Order Date  Ship Date       Ship Mode     Customer Name      Segment  \
# 5274 2016-11-07 2016-11-09    Second Class  Stewart Visinsky     Consumer
# 9741 2016-11-08 2016-11-12  Standard Class      Quincy Jones    Corporate
# 9146 2017-01-23 2017-01-27  Standard Class  Claudia Bergmann    Corporate
# 9148 2017-01-23 2017-01-27  Standard Class  Claudia Bergmann    Corporate
# 9147 2017-01-23 2017-01-27  Standard Class  Claudia Bergmann    Corporate
# 8798 2017-04-06 2017-04-10  Standard Class   Valerie Mitchum  Home Office
# 9388 2018-01-19 2018-01-23  Standard Class     Raymond Messe     Consumer
# 9389 2018-01-19 2018-01-23  Standard Class     Raymond Messe     Consumer
# 9387 2018-01-19 2018-01-23  Standard Class     Raymond Messe     Consumer
# 9386 2018-01-19 2018-01-23  Standard Class     Raymond Messe     Consumer
# 2234 2018-12-05 2018-12-10  Standard Class      Quincy Jones    Corporate
#
#             Country        City    State  Postal Code Region       Product ID  \
# 5274  United States  Burlington  Vermont          NaN   East  FUR-CH-10000595
# 9741  United States  Burlington  Vermont          NaN   East  FUR-BO-10004834
# 9146  United States  Burlington  Vermont          NaN   East  TEC-AC-10002926
# 9148  United States  Burlington  Vermont          NaN   East  OFF-ST-10001526
# 9147  United States  Burlington  Vermont          NaN   East  OFF-AR-10003477
# 8798  United States  Burlington  Vermont          NaN   East  TEC-PH-10002555
# 9388  United States  Burlington  Vermont          NaN   East  OFF-AP-10000828
# 9389  United States  Burlington  Vermont          NaN   East  OFF-EN-10001509
# 9387  United States  Burlington  Vermont          NaN   East  OFF-PA-10001970
# 9386  United States  Burlington  Vermont          NaN   East  OFF-PA-10000157
# 2234  United States  Burlington  Vermont          NaN   East  TEC-AC-10001013
#
#              Category Sub-Category  \
# 5274        Furniture       Chairs
# 9741        Furniture    Bookcases
# 9146       Technology  Accessories
# 9148  Office Supplies      Storage
# 9147  Office Supplies          Art
# 8798       Technology       Phones
# 9388  Office Supplies   Appliances
# 9389  Office Supplies    Envelopes
# 9387  Office Supplies        Paper
# 9386  Office Supplies        Paper
# 2234       Technology  Accessories
#
#                                            Product Name    Sales
# 5274                    Safco Contoured Stacking Chairs   715.20
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90
# 9146              Logitech Wireless Marathon Mouse M705    99.98
# 9148              Iceberg Mobile Mega Data/Printer Cart  1564.29
# 9147                                  4009 Highlighters     8.04
# 8798                Nortel Meridian M5316 Digital phone  1294.75
# 9388                    Avanti 4.4 Cu. Ft. Refrigerator   542.94
# 9389                          Poly String Tie Envelopes     2.04
# 9387                                         Xerox 1881    12.28
# 9386                                          Xerox 191    79.92
# 2234        Logitech ClearChat Comfort/USB Headset H390   205.03

# %%
 # Replacing null postal code for Burlington city
df['Postal Code'] = df['Postal Code'].fillna(5401)

# %%
df.isnull().sum()
# Out:
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9800 entries, 7980 to 5091
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9800 non-null   datetime64[ns]
#  1   Ship Date      9800 non-null   datetime64[ns]
#  2   Ship Mode      9800 non-null   object
#  3   Customer Name  9800 non-null   object
#  4   Segment        9800 non-null   object
#  5   Country        9800 non-null   object
#  6   City           9800 non-null   object
#  7   State          9800 non-null   object
#  8   Postal Code    9800 non-null   float64
#  9   Region         9800 non-null   object
#  10  Product ID     9800 non-null   object
#  11  Category       9800 non-null   object
#  12  Sub-Category   9800 non-null   object
#  13  Product Name   9800 non-null   object
#  14  Sales          9800 non-null   float64
# dtypes: datetime64[ns](2), float64(2), object(11)
# memory usage: 1.2+ MB

# %% [markdown]
# # Exploratory data analysis
